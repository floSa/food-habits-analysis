# %%
import pandas as pd

file_path = 'enquete_alimentation.csv'

# Lire le fichier CSV
data = pd.read_csv(file_path, delimiter=';')
data
# Out:
#                          Date   Sexe    Age   Rura Card    Etud  \
# 0     2021-11-19 17:42:13.035  Femme    +60  Rural  Sud     Bac
# 1     2021-11-19 17:54:33.540  Femme  18-34  Rural  Sud     Bac
# 2     2021-11-19 17:59:52.318  Homme    +60  Rural  Sud     Bac
# 3     2021-11-19 18:03:47.127  Femme  18-34  Citad  Sud     Bac
# 4     2021-11-19 19:15:13.357  Homme  18-34  Rural  Sud     Bac
# ...                       ...    ...    ...    ...  ...     ...
# 1676  2021-12-01 15:51:20.997  Homme  35-60  Citad  Sud  Bac +5
# 1677  2021-12-02 11:06:03.621  Homme  35-60  Rural  Sud   Bac+3
# 1678  2021-12-03 23:21:55.182  Femme  18-34  Citad  Sud   Bac+3
# 1679  2021-12-06 08:08:02.385  Homme  35-60  Rural  Sud     Bac
# 1680  2021-12-06 10:25:02.959  Femme  35-60  Citad  Sud  Bac +5
#
#                       pro parent parent2 Retraite  ... VF_saut  VF_Eq_Reg  \
# 0                Retraité    NaN     NaN  Salarié  ...     Non        Non
# ...
